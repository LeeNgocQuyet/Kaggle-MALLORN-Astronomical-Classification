# %%
# 1. Imports and basic config
import os
import gc
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## 2. How to run long steps
# - For heavy feature extraction: `!python src/data_processing.py --base-path data/raw --mode train`
# - For training: `!python src/model_training.py --base-path data/raw --out submission.csv`
#
# ## 3. Lightweight example run
# Use small subsets or cached `data/processed/*.parquet` to run quickly in the notebook.
